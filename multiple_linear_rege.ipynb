# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("multiple_linear_regression_dataset.csv")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

x= df[['age', 'experience']]
y = df['income']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)

prediction = model.predict([[25, 2]]) 
print("Predicted income:", prediction[0])

plt.scatter(df['age'], y, color='blue')
plt.xlabel("Age")
plt.ylabel("Income")
plt.title("Age vs Income")
plt.show()
# Out:
# Coefficients: [-101.0592335  2154.80549277]
# Intercept: 31465.056418503933
# Predicted income: 33248.18656653104
# C:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv("multiple_linear_regression_dataset.csv")

x=df[['age','experience']]
y=df['income']
x_train,x_test,y_train,y_test=train_test_split(
    x,y,test_size=0.2,random_state=42
)
model=LinearRegression()
model.fit(x_train,y_train)
pred=model.predict(x_test)
print("Predictions:", pred)
x1=df["age"]
x2=df["experience"]
y=df["income"]
x1_range = np.linspace(x1.min(), x1.max(), 10)
x2_range = np.linspace(x2.min(), x2.max(), 10)
X1_grid, X2_grid = np.meshgrid(x1_range, x2_range)
Y_pred = model.predict(np.column_stack((X1_grid.ravel(), X2_grid.ravel())))
Y_pred = Y_pred.reshape(X1_grid.shape)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x1, x2, y, color='red', s=50, label='Actual Data')
surf = ax.plot_surface(X1_grid, X2_grid, Y_pred, alpha=0.4, cmap='viridis')
ax.set_xlabel("Age")
ax.set_ylabel("Experience")
ax.set_zlabel("Income")
ax.set_title("Income Prediction Plane vs Actual Data")
plt.legend()
plt.show()
# Out:
# Predictions: [31093.38107376 31295.49954076 40250.46080162 34897.6958918 ]
# C:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
